# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('fight-with-covid-19-challenge/world_data.csv')
df1
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
df1.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
df1.drop(['NewCases', 'NewDeaths', 'NewRecovered'], axis = 1, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Country/Region       0
# Continent            1
# Population           1
# TotalCases           0
# TotalDeaths         21
# TotalRecovered       4
# ActiveCases          4
# Serious,Critical    87
# Tot Cases/1M pop     1
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
df = pd.read_csv('fight-with-covid-19-challenge/covid_19_complete.csv')
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
df.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
df.drop(['Province/State'], axis = 1, inplace=True)

# %%
df
# Out:
#               Country/Region        Lat       Long        Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953  2020-01-22          0
# 1                    Albania  41.153300  20.168300  2020-01-22          0
# 2                    Algeria  28.033900   1.659600  2020-01-22          0
# 3                    Andorra  42.506300   1.521800  2020-01-22          0
# 4                     Angola -11.202700  17.873900  2020-01-22          0
# ...                      ...        ...        ...         ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100  2020-07-27        865
# 49064                  Yemen  15.552727  48.516388  2020-07-27       1691
# 49065                Comoros -11.645500  43.333300  2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100  2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600  2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region
# ...

# %%
df['Current'] = df['Confirmed'] - df['Deaths'] - df['Recovered']

# %%
df
# Out:
#               Country/Region        Lat       Long        Date  Confirmed  \
# 0                Afghanistan  33.939110  67.709953  2020-01-22          0
# 1                    Albania  41.153300  20.168300  2020-01-22          0
# 2                    Algeria  28.033900   1.659600  2020-01-22          0
# 3                    Andorra  42.506300   1.521800  2020-01-22          0
# 4                     Angola -11.202700  17.873900  2020-01-22          0
# ...                      ...        ...        ...         ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100  2020-07-27        865
# 49064                  Yemen  15.552727  48.516388  2020-07-27       1691
# 49065                Comoros -11.645500  43.333300  2020-07-27        354
# 49066             Tajikistan  38.861000  71.276100  2020-07-27       7235
# 49067                Lesotho -29.610000  28.233600  2020-07-27        505
#
#        Deaths  Recovered  Active             WHO Region  Current
# ...

# %%
df_new = df.groupby('Date')[['Confirmed', 'Deaths', 'Recovered', 'Current']].sum()

# %%
df_new
# Out:
#             Confirmed  Deaths  Recovered  Current
# Date
# 2020-01-22        555      17         28      510
# 2020-01-23        654      18         30      606
# 2020-01-24        941      26         36      879
# 2020-01-25       1434      42         39     1353
# 2020-01-26       2118      56         52     2010
# ...               ...     ...        ...      ...
# 2020-07-23   15510481  633506    8710969  6166006
# 2020-07-24   15791645  639650    8939705  6212290
# 2020-07-25   16047190  644517    9158743  6243930
# 2020-07-26   16251796  648621    9293464  6309711
# 2020-07-27   16480485  654036    9468087  6358362
#
# [188 rows x 4 columns]

# %%
plt.figure(figsize = [20, 15])
plt.plot(df_new['Confirmed'], color = 'g', label = 'Confirmed')
plt.plot(df_new['Deaths'], color = 'r', label = 'Deaths')
plt.plot(df_new['Recovered'], color = 'b', label = 'Recovered')
plt.plot(df_new['Current'], color = 'k', label = 'Current')
plt.legend()
